# %% [markdown]
# # Dataset Description

# %% [markdown]
# ## The dataset contains information about road traffic accidents with the following columns:
#
# `Time`: Time of the accident
#
# `Day_of_week`: Day of the week when the accident occurred
#
# `Age_band_of_driver`: Age group of the driver
#
# `Sex_of_driver`: Gender of the driver
#
# `Educational_level`: Educational level of the driver
#
# `Vehicle_driver_relation`: Relationship of the driver to the vehicle
#
# `Driving_experience`: Driving experience of the driver
#
# `Type_of_vehicle`: Type of vehicle involved in the accident
#
# `Owner_of_vehicle`: Owner of the vehicle
#
# `Service_year_of_vehicle`: Service years of the vehicle
#
# `Area_accident_occured`: Area where the accident occurred
#
# `Lanes_or_Medians`: Lanes or medians at the accident site
#
# `Road_allignment`: Road alignment at the accident site
#
# `Types_of_Junction`: Type of junction at the accident site
#
# `Road_surface_type`: Type of road surface at the accident site
#
# `Road_surface_conditions`: Road surface conditions at the accident site
#
# `Light_conditions`: Light conditions at the time of the accident
#
# `Weather_conditions`: Weather conditions at the time of the accident
#
# `Type_of_collision`: Type of collision
#
# `Number_of_vehicles_involved`: Number of vehicles involved in the accident
#
# `Number_of_casualties`: Number of casualties in the accident
#
# `Vehicle_movement`: Movement of the vehicle during the accident
#
# `Casualty_class`: Class of casualty (driver, passenger, pedestrian)
#
# `Sex_of_casualty`: Gender of the casualty
#
# `Age_band_of_casualty`: Age group of the casualty
#
# `Casualty_severity`: Severity of the casualty
#
# `Work_of_casuality`: Occupation of the casualty
#
# `Fitness_of_casuality`: Fitness of the casualty
#
# `Pedestrian_movement`: Movement of the pedestrian
#
# `Cause_of_accident`: Cause of the accident
#
# `Accident_severity`: Severity of the accident

# %% [markdown]
# # Tasks

# %% [markdown]
# ## 1. Data Cleaning

# %% [markdown]
# ### Read the dataset

# %%
#%pip install pandas

# %%
# import pandas
#import pandas as pd

# %%
import pandas as pd

# Read
df = pd.read_csv("Task (1) Dataset.csv")

df.head()
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00      Monday              18-30          Male   Above high school
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 2  17:02:00      Monday              18-30          Male  Junior high school
# 3   1:06:00      Sunday              18-30          Male  Junior high school
# 4   1:06:00      Sunday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 2                Employee              1-2yr      Lorry (41?100Q)
# 3                Employee             5-10yr  Public (> 45 seats)
# 4                Employee              2-5yr                  NaN
#
#   Owner_of_vehicle Service_year_of_vehicle  ... Vehicle_movement  \
# ...

# %% [markdown]
# ### Handle Missing Values

# %%
#Checking for a missing values
cols_missing_val = [col for col in df.columns if df[col].isnull().any()]

# a list of columns with a missing values
print(cols_missing_val, '\n')

# The total of null values
print(df.isnull().sum())
# Out:
# ['Educational_level', 'Vehicle_driver_relation', 'Driving_experience', 'Type_of_vehicle', 'Owner_of_vehicle', 'Service_year_of_vehicle', 'Defect_of_vehicle', 'Area_accident_occured', 'Lanes_or_Medians', 'Road_allignment', 'Types_of_Junction', 'Road_surface_type', 'Type_of_collision', 'Vehicle_movement', 'Work_of_casuality', 'Fitness_of_casuality']
#
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               741
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        3928
# Defect_of_vehicle              4427
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                 142
# Types_of_Junction               887
# Road_surface_type               172
# Road_surface_conditions           0
# ...

# %%
# importing the simpleImputer
from sklearn.impute import SimpleImputer

# Handling the missing values in New_Price columns by using drop approach
drop_values = df.dropna(subset=['Service_year_of_vehicle'], inplace=True)
drop_values2 = df.dropna(subset=['Defect_of_vehicle'], inplace=True)
drop_values3 = df.dropna(subset=['Fitness_of_casuality'], inplace=True)

# %%
# Handling the missing values by using Imputation technique
myImputer = SimpleImputer()

# take the numerical data only
imputed_data = pd.DataFrame (myImputer.fit_transform(df.select_dtypes(exclude=['object'])))

imputed_data
# Out:
#         0    1
# 0     2.0  1.0
# 1     2.0  1.0
# 2     2.0  1.0
# 3     2.0  1.0
# 4     2.0  2.0
# ...   ...  ...
# 4384  2.0  1.0
# 4385  1.0  1.0
# 4386  1.0  1.0
# 4387  2.0  1.0
# 4388  2.0  1.0
#
# [4389 rows x 2 columns]

# %%
# Checking for null values
df.isnull().sum()
# Out:
# Time                             0
# Day_of_week                      0
# Age_band_of_driver               0
# Sex_of_driver                    0
# Educational_level              213
# Vehicle_driver_relation        171
# Driving_experience             248
# Type_of_vehicle                305
# Owner_of_vehicle                28
# Service_year_of_vehicle          0
# Defect_of_vehicle                0
# Area_accident_occured           54
# Lanes_or_Medians                85
# Road_allignment                 22
# Types_of_Junction              339
# Road_surface_type               66
# Road_surface_conditions          0
# Light_conditions                 0
# Weather_conditions               0
# Type_of_collision               72
# Number_of_vehicles_involved      0
# Number_of_casualties             0
# Vehicle_movement               112
# Casualty_class                   0
# Sex_of_casualty                  0
# Age_band_of_casualty             0
# Casualty_severity                0
# ...

# %% [markdown]
# ### Correct any inconsistent data entries
#
# - values out of the ordinary?
# - mixed-case (captial and small)?
# - units?
# - ...etc.

# %%
date_series = pd.Series(df['Time'])
date_series = pd.to_datetime(date_series)


#df['Time_UTC'] = df['Time'].dt.tz_convert('US/Eastren')
# Out:
# C:\Users\amani\AppData\Local\Temp\ipykernel_26956\2797048157.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   date_series = pd.to_datetime(date_series)
# str

# %% [markdown]
# ### Ensure data types are appropriate for each column.
#
# - numerical but object?
# - date but object?
# - ...etc.

# %%
# printing the data type for each colunms
print(df.dtypes, '\n')
# Out:
# Time                           object
# Day_of_week                    object
# Age_band_of_driver             object
# Sex_of_driver                  object
# Educational_level              object
# Vehicle_driver_relation        object
# Driving_experience             object
# Type_of_vehicle                object
# Owner_of_vehicle               object
# Service_year_of_vehicle        object
# Defect_of_vehicle              object
# Area_accident_occured          object
# Lanes_or_Medians               object
# Road_allignment                object
# Types_of_Junction              object
# Road_surface_type              object
# Road_surface_conditions        object
# Light_conditions               object
# Weather_conditions             object
# Type_of_collision              object
# Number_of_vehicles_involved     int64
# Number_of_casualties            int64
# Vehicle_movement               object
# Casualty_class                 object
# Sex_of_casualty                object
# ...

# %% [markdown]
# ## 2. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Perform summary statistics on the dataset

# %%
#get a concise summary of the Data Frame.
print(df.info(), '\n \n \n')

#get statistical summary
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4389 entries, 7 to 12315
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         4389 non-null   object
#  1   Day_of_week                  4389 non-null   object
#  2   Age_band_of_driver           4389 non-null   object
#  3   Sex_of_driver                4389 non-null   object
#  4   Educational_level            4176 non-null   object
#  5   Vehicle_driver_relation      4218 non-null   object
#  6   Driving_experience           4141 non-null   object
#  7   Type_of_vehicle              4084 non-null   object
#  8   Owner_of_vehicle             4361 non-null   object
#  9   Service_year_of_vehicle      4389 non-null   object
#  10  Defect_of_vehicle            4389 non-null   object
#  11  Area_accident_occured        4335 non-null   object
#  12  Lanes_or_Medians             4304 non-null   object
# ...

# %% [markdown]
# ### Identify and analyze patterns in the data
#
# - heatmap

# %%
# the numirical columns
numirical_cols = df.select_dtypes('number')

# calculating the corrlation matrix
corr_matrix = numirical_cols.corr()

print(corr_matrix)
# Out:
#                              Number_of_vehicles_involved  Number_of_casualties
# Number_of_vehicles_involved                     1.000000              0.195015
# Number_of_casualties                            0.195015              1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Representing the correlation matrix by using heatmap

plt.figure(figsize=(8,5))
sns.heatmap(corr_matrix,annot=True)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ### Visualize the distribution of key variables (e.g., Age_band_of_driver, Type_of_vehicle).

# %%
sns.violinplot(data=df, x="Age_band_of_driver", y="Type_of_vehicle")
# Out:
# <Axes: xlabel='Age_band_of_driver', ylabel='Type_of_vehicle'>

# %% [markdown]
# ### Explore relationships between variables (e.g., Age_band_of_driver vs. Accident_severity).

# %%
df.plot.scatter(x='Age_band_of_driver', y='Accident_severity')
# Out:
# <Axes: xlabel='Age_band_of_driver', ylabel='Accident_severity'>

# %% [markdown]
# ## 3. Data Visualization

# %% [markdown]
# * Ensure the visualizations are clear and informative.

# %% [markdown]
# ### Create visualizations to illustrate the findings from the EDA.

# %%
sns.pairplot(df)

# %% [markdown]
# ### Use appropriate plots such as histograms, bar charts, pie charts, scatter plots, and heatmaps.

# %%
#df.select_dtypes('number').plot.pie(subplots=True, figsize=(3, 2))


# Histogram for total crashes
'''plt.figure(figsize=(20, 10))
sns.histplot(df[['Price'],['Year']], kde=True, bins=20, color='blue')
plt.title('Histogram of Total Price per Country')
plt.xlabel('Price')
plt.ylabel('Year')
plt.show()'''

sns.histplot(data=df, x="Accident_severity")
# Out:
# <Axes: xlabel='Accident_severity', ylabel='Count'>

# %% [markdown]
# ## 4. Insights and Conclusions

# %% [markdown]
# * <h3>Summarize the key insights gained from the data analysis.<h3/>
# * <h3>Draw conclusions based on the patterns observed in the data.<h3/>
